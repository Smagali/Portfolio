# %% [markdown]
# <a href="https://colab.research.google.com/github/Smagali/Portfolio/blob/main/PARAMETROS_PAMI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import scipy.stats as ss
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels
from patsy import dmatrices
from statistics import mean
import plotly.graph_objects as go
from charset_normalizer import detect
from google.colab import drive

drive.mount('/content/drive', force_remount=True)

filepath1= '/content/drive/MyDrive/Carpeta sin título/1sem_2022.xls.csv'
filepath2 = '/content/drive/MyDrive/Carpeta sin título/2-SEM.xls.csv'


with open(filepath1, 'rb') as f:
    result = detect(f.read())
    print(result['encoding'])

with open(filepath2, 'rb') as g:
    result2 = detect(g.read())
    print(result2['encoding'])
# Out:
# Mounted at /content/drive
# windows-1250
# windows-1250

# %%
SEPT_MAR = pd.read_csv(filepath1, encoding=result['encoding'])
ABR_AGO = pd.read_csv(filepath2, encoding=result2['encoding'])

ABR_AGO.columns = SEPT_MAR.columns
ABR_AGO = ABR_AGO[1:]

append_data = pd.concat([SEPT_MAR, ABR_AGO], ignore_index=True)

num_Data = len(SEPT_MAR)
num_Data2 = len(ABR_AGO)
num_total = len(append_data)

#Lectura de campo "FECHA_TURNO" de tipo cadena de texto para convertir en datetime
append_data['FECHA_TURNO'] = append_data['FECHA_TURNO'].astype(str)

append_data['FECHA_TURNO'] = append_data['FECHA_TURNO'].str.slice(0, 10) #Se corta en 10 caracteres que son de la fecha (00-00-0000)
append_data['FECHA_TURNO'] = pd.to_datetime(append_data['FECHA_TURNO'], format='%d/%m/%Y', dayfirst=True)

print(num_total)
# Out:
# 17329

# %%
# Crear la expresión regular para buscar cualquiera de los valores
expresion_regular = "429001|429002|429003"

# Filtro
fecha_inicio = pd.to_datetime('01/09/2022', dayfirst=True, format='%d/%m/%Y')
fecha_fin = pd.to_datetime('31/08/2023', dayfirst=True, format='%d/%m/%Y')

filtroA = (
    append_data['PRACTICA'].str.contains(expresion_regular, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio) &
    (append_data['FECHA_TURNO'] <= fecha_fin)
)
modulo_36 = append_data[filtroA]
num_consultas= len(modulo_36)


###
# Filtro de primera consulta 1
fecha_inicio1 = pd.to_datetime('01/09/2022', dayfirst=True, format='%d/%m/%Y')
fecha_fin1 = pd.to_datetime('30/09/2022', dayfirst=True, format='%d/%m/%Y')

filtro1 = (
    append_data['PRACTICA'].str.contains(expresion_regular, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio1) &
    (append_data['FECHA_TURNO'] <= fecha_fin1)
)

primera_1 = append_data[filtro1]
num_consulta1= len(primera_1)

# Filtro de primera consulta 2
fecha_inicio2 = pd.to_datetime('01/10/2022', dayfirst=True, format='%d/%m/%Y')
fecha_fin2 = pd.to_datetime('31/10/2022', dayfirst=True, format='%d/%m/%Y')

filtro2 = (
    append_data['PRACTICA'].str.contains(expresion_regular, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio2) &
    (append_data['FECHA_TURNO'] <= fecha_fin2)
)

primera_2 = append_data[filtro2]
num_consulta2= len(primera_2)

# Filtro de primera consulta 3
fecha_inicio3 = pd.to_datetime('01/11/2022', dayfirst=True, format='%d/%m/%Y')
fecha_fin3 = pd.to_datetime('30/11/2022', dayfirst=True, format='%d/%m/%Y')

filtro3 = (
    append_data['PRACTICA'].str.contains(expresion_regular, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio3) &
    (append_data['FECHA_TURNO'] <= fecha_fin3)
)

primera_3 = append_data[filtro3]
num_consulta3= len(primera_3)

# Filtro de primera consulta 4
fecha_inicio4 = pd.to_datetime('01/12/2022', dayfirst=True, format='%d/%m/%Y')
fecha_fin4 = pd.to_datetime('31/12/2022', dayfirst=True, format='%d/%m/%Y')

filtro4 = (
    append_data['PRACTICA'].str.contains(expresion_regular, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio4) &
    (append_data['FECHA_TURNO'] <= fecha_fin4)
)

primera_4 = append_data[filtro4]
num_consulta4= len(primera_4)

# Filtro de primera consulta 5
fecha_inicio5 = pd.to_datetime('01/01/2023', dayfirst=True, format='%d/%m/%Y')
fecha_fin5 = pd.to_datetime('31/01/2023', dayfirst=True, format='%d/%m/%Y')

filtro5 = (
    append_data['PRACTICA'].str.contains(expresion_regular, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio5) &
    (append_data['FECHA_TURNO'] <= fecha_fin5)
)

primera_5 = append_data[filtro5]
num_consulta5= len(primera_5)

# Filtro de primera consulta 6
fecha_inicio6 = pd.to_datetime('01/02/2023', dayfirst=True, format='%d/%m/%Y')
fecha_fin6 = pd.to_datetime('28/02/2023', dayfirst=True, format='%d/%m/%Y')

filtro6 = (
    append_data['PRACTICA'].str.contains(expresion_regular, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio6) &
    (append_data['FECHA_TURNO'] <= fecha_fin6)
)

primera_6 = append_data[filtro6]
num_consulta6= len(primera_6)

# Filtro de primera consulta 7
fecha_inicio7 = pd.to_datetime('01/03/2023', dayfirst=True, format='%d/%m/%Y')
fecha_fin7 = pd.to_datetime('31/03/2023', dayfirst=True, format='%d/%m/%Y')

filtro7 = (
    append_data['PRACTICA'].str.contains(expresion_regular, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio7) &
    (append_data['FECHA_TURNO'] <= fecha_fin7)
)

primera_7 = append_data[filtro7]
num_consulta7= len(primera_7)

# Filtro de primera consulta 8
fecha_inicio8 = pd.to_datetime('01/04/2023', dayfirst=True, format='%d/%m/%Y')
fecha_fin8 = pd.to_datetime('30/04/2023', dayfirst=True, format='%d/%m/%Y')

filtro8 = (
    append_data['PRACTICA'].str.contains(expresion_regular, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio8) &
    (append_data['FECHA_TURNO'] <= fecha_fin8)
)

primera_8 = append_data[filtro8]
num_consulta8= len(primera_8)

# Filtro de primera consulta 9
fecha_inicio9 = pd.to_datetime('01/05/2023', dayfirst=True, format='%d/%m/%Y')
fecha_fin9 = pd.to_datetime('30/05/2023', dayfirst=True, format='%d/%m/%Y')

filtro9 = (
    append_data['PRACTICA'].str.contains(expresion_regular, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio9) &
    (append_data['FECHA_TURNO'] <= fecha_fin9)
)

primera_9 = append_data[filtro9]
num_consulta9= len(primera_9)

# Filtro de primera consulta 10
fecha_inicio10 = pd.to_datetime('01/06/2023', dayfirst=True, format='%d/%m/%Y')
fecha_fin10 = pd.to_datetime('30/06/2023', dayfirst=True, format='%d/%m/%Y')

filtro10 = (
    append_data['PRACTICA'].str.contains(expresion_regular, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio10) &
    (append_data['FECHA_TURNO'] <= fecha_fin10)
)

primera_10 = append_data[filtro10]
num_consulta10= len(primera_10)

# Filtro de primera consulta 11
fecha_inicio11 = pd.to_datetime('01/07/2023', dayfirst=True, format='%d/%m/%Y')
fecha_fin11 = pd.to_datetime('31/07/2023', dayfirst=True, format='%d/%m/%Y')

filtro11 = (
    append_data['PRACTICA'].str.contains(expresion_regular, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio11) &
    (append_data['FECHA_TURNO'] <= fecha_fin11)
)

primera_11 = append_data[filtro11]
num_consulta11= len(primera_11)

# Filtro de primera consulta 12
fecha_inicio12 = pd.to_datetime('01/08/2023', dayfirst=True, format='%d/%m/%Y')
fecha_fin12 = pd.to_datetime('30/08/2023', dayfirst=True, format='%d/%m/%Y')

filtro12 = (
    append_data['PRACTICA'].str.contains(expresion_regular, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio12) &
    (append_data['FECHA_TURNO'] <= fecha_fin12)
)

primera_12 = append_data[filtro12]
num_consulta12= len(primera_12)


# Datos de número de consultas
num_consultas = [
    num_consulta1, num_consulta2, num_consulta3, num_consulta4,
    num_consulta5, num_consulta6, num_consulta7, num_consulta8,
    num_consulta9, num_consulta10, num_consulta11, num_consulta12
]

promedio = np.mean(num_consultas)
print("Promedio de registros por mes:", promedio)

# Etiquetas de los filtros
etiquetas = [
    "Septiembre 2022", "Octubre 2022", "Noviembre 2022", "Diciembre 2022",
    "Enero 2023", "Febrero 2023", "Marzo 2023", "Abril 2023",
    "Mayo 2023", "Junio 2023", "Julio 2023", "Agosto 2023"
]

fig = go.Figure()

fig.add_trace(
    go.Bar(
        x=etiquetas,
        y=num_consultas,
        text=num_consultas,
        textposition='auto',
        marker_color='purple',
        marker_line_color='black',
        marker_line_width=1.5,
    )
)

# Línea del promedio
fig.add_trace(
    go.Scatter(
        x=etiquetas,
        y=[promedio] * len(etiquetas),
        mode='lines',
        name=f"Promedio: {promedio:.2f}",
        line=dict(color='red', dash='dash'),
    )
)


fig.update_layout(
    title="Cantidad de practicas dentro de módulo 36 (consultas)",
    xaxis_title="Mes",
    yaxis_title="Número de registros",
    xaxis_tickangle=-45,
    template="plotly_white"
)
fig.show()
# Out:
# Promedio de registros por mes: 823.8333333333334
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Crear la expresión regular para buscar cualquiera de los valores
expresion_regular2 = "505001|505002|505003|505006|505012|505014"

# Definir el filtro
filtroy = (
    append_data['PRACTICA'].str.contains(expresion_regular2, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio) &
    (append_data['FECHA_TURNO'] <= fecha_fin)
)

# Aplicar el filtro
modulo_38 = append_data[filtroy]
modulo38 = len(modulo_38)

# Mostrar resultados
print(f"Número de registros total: {modulo38}")

# Filtro de primera consulta 1
fecha_inicio1 = pd.to_datetime('01/09/2022', dayfirst=True, format='%d/%m/%Y')
fecha_fin1 = pd.to_datetime('30/09/2022', dayfirst=True, format='%d/%m/%Y')

filtro1 = (
    append_data['PRACTICA'].str.contains(expresion_regular2, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio1) &
    (append_data['FECHA_TURNO'] <= fecha_fin1)
)

primera_1 = append_data[filtro1]
num_consulta1= len(primera_1)

# Filtro de primera consulta 2
fecha_inicio2 = pd.to_datetime('01/10/2022', dayfirst=True, format='%d/%m/%Y')
fecha_fin2 = pd.to_datetime('31/10/2022', dayfirst=True, format='%d/%m/%Y')

filtro2 = (
    append_data['PRACTICA'].str.contains(expresion_regular2, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio2) &
    (append_data['FECHA_TURNO'] <= fecha_fin2)
)

primera_2 = append_data[filtro2]
num_consulta2= len(primera_2)

# Filtro de primera consulta 3
fecha_inicio3 = pd.to_datetime('01/11/2022', dayfirst=True, format='%d/%m/%Y')
fecha_fin3 = pd.to_datetime('30/11/2022', dayfirst=True, format='%d/%m/%Y')

filtro3 = (
    append_data['PRACTICA'].str.contains(expresion_regular2, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio3) &
    (append_data['FECHA_TURNO'] <= fecha_fin3)
)

primera_3 = append_data[filtro3]
num_consulta3= len(primera_3)

# Filtro de primera consulta 4
fecha_inicio4 = pd.to_datetime('01/12/2022', dayfirst=True, format='%d/%m/%Y')
fecha_fin4 = pd.to_datetime('31/12/2022', dayfirst=True, format='%d/%m/%Y')

filtro4 = (
    append_data['PRACTICA'].str.contains(expresion_regular2, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio4) &
    (append_data['FECHA_TURNO'] <= fecha_fin4)
)

primera_4 = append_data[filtro4]
num_consulta4= len(primera_4)

# Filtro de primera consulta 5
fecha_inicio5 = pd.to_datetime('01/01/2023', dayfirst=True, format='%d/%m/%Y')
fecha_fin5 = pd.to_datetime('31/01/2023', dayfirst=True, format='%d/%m/%Y')

filtro5 = (
    append_data['PRACTICA'].str.contains(expresion_regular2, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio5) &
    (append_data['FECHA_TURNO'] <= fecha_fin5)
)

primera_5 = append_data[filtro5]
num_consulta5= len(primera_5)

# Filtro de primera consulta 6
fecha_inicio6 = pd.to_datetime('01/02/2023', dayfirst=True, format='%d/%m/%Y')
fecha_fin6 = pd.to_datetime('28/02/2023', dayfirst=True, format='%d/%m/%Y')

filtro6 = (
    append_data['PRACTICA'].str.contains(expresion_regular2, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio6) &
    (append_data['FECHA_TURNO'] <= fecha_fin6)
)

primera_6 = append_data[filtro6]
num_consulta6= len(primera_6)

# Filtro de primera consulta 7
fecha_inicio7 = pd.to_datetime('01/03/2023', dayfirst=True, format='%d/%m/%Y')
fecha_fin7 = pd.to_datetime('31/03/2023', dayfirst=True, format='%d/%m/%Y')

filtro7 = (
    append_data['PRACTICA'].str.contains(expresion_regular2, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio7) &
    (append_data['FECHA_TURNO'] <= fecha_fin7)
)

primera_7 = append_data[filtro7]
num_consulta7= len(primera_7)

# Filtro de primera consulta 8
fecha_inicio8 = pd.to_datetime('01/04/2023', dayfirst=True, format='%d/%m/%Y')
fecha_fin8 = pd.to_datetime('30/04/2023', dayfirst=True, format='%d/%m/%Y')

filtro8 = (
    append_data['PRACTICA'].str.contains(expresion_regular2, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio8) &
    (append_data['FECHA_TURNO'] <= fecha_fin8)
)

primera_8 = append_data[filtro8]
num_consulta8= len(primera_8)

# Filtro de primera consulta 9
fecha_inicio9 = pd.to_datetime('01/05/2023', dayfirst=True, format='%d/%m/%Y')
fecha_fin9 = pd.to_datetime('30/05/2023', dayfirst=True, format='%d/%m/%Y')

filtro9 = (
    append_data['PRACTICA'].str.contains(expresion_regular2, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio9) &
    (append_data['FECHA_TURNO'] <= fecha_fin9)
)

primera_9 = append_data[filtro9]
num_consulta9= len(primera_9)

# Filtro de primera consulta 10
fecha_inicio10 = pd.to_datetime('01/06/2023', dayfirst=True, format='%d/%m/%Y')
fecha_fin10 = pd.to_datetime('30/06/2023', dayfirst=True, format='%d/%m/%Y')

filtro10 = (
    append_data['PRACTICA'].str.contains(expresion_regular2, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio10) &
    (append_data['FECHA_TURNO'] <= fecha_fin10)
)

primera_10 = append_data[filtro10]
num_consulta10= len(primera_10)

# Filtro de primera consulta 11
fecha_inicio11 = pd.to_datetime('01/07/2023', dayfirst=True, format='%d/%m/%Y')
fecha_fin11 = pd.to_datetime('31/07/2023', dayfirst=True, format='%d/%m/%Y')

filtro11 = (
    append_data['PRACTICA'].str.contains(expresion_regular2, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio11) &
    (append_data['FECHA_TURNO'] <= fecha_fin11)
)

primera_11 = append_data[filtro11]
num_consulta11= len(primera_11)

# Filtro de primera consulta 12
fecha_inicio12 = pd.to_datetime('01/08/2023', dayfirst=True, format='%d/%m/%Y')
fecha_fin12 = pd.to_datetime('30/08/2023', dayfirst=True, format='%d/%m/%Y')

filtro12 = (
    append_data['PRACTICA'].str.contains(expresion_regular2, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio12) &
    (append_data['FECHA_TURNO'] <= fecha_fin12)
)

primera_12 = append_data[filtro12]
num_consulta12= len(primera_12)


# Datos de número de consultas
num_consultas = [
    num_consulta1, num_consulta2, num_consulta3, num_consulta4,
    num_consulta5, num_consulta6, num_consulta7, num_consulta8,
    num_consulta9, num_consulta10, num_consulta11, num_consulta12
]

promedio = np.mean(num_consultas)
print("Promedio de registros por mes:", promedio)

# Etiquetas de los filtros
etiquetas = [
    "Septiembre 2022", "Octubre 2022", "Noviembre 2022", "Diciembre 2022",
    "Enero 2023", "Febrero 2023", "Marzo 2023", "Abril 2023",
    "Mayo 2023", "Junio 2023", "Julio 2023", "Agosto 2023"
]

fig = go.Figure()

fig.add_trace(
    go.Bar(
        x=etiquetas,
        y=num_consultas,
        text=num_consultas,
        textposition='auto',
        marker_color='purple',
        marker_line_color='black',
        marker_line_width=1.5,
    )
)

# Línea del promedio
fig.add_trace(
    go.Scatter(
        x=etiquetas,
        y=[promedio] * len(etiquetas),
        mode='lines',
        name=f"Promedio: {promedio:.2f}",
        line=dict(color='red', dash='dash'),
    )
)


fig.update_layout(
    title="Cantidad de practicas dentro de módulo 38 (estudios)",
    xaxis_title="Mes",
    yaxis_title="Número de registros",
    xaxis_tickangle=-45,
    template="plotly_white"
)
fig.show()
# Out:
# Número de registros total: 4661
# Promedio de registros por mes: 376.1666666666667
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Crear la expresión regular para buscar cualquiera de los valores
expresion_regular3 = "500007|500011|500030|500031|500038|500039|500040"

# Definir el filtro
filtrox = (
    append_data['PRACTICA'].str.contains(expresion_regular3, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio) &
    (append_data['FECHA_TURNO'] <= fecha_fin)
)

# Aplicar el filtro
modulo_37 = append_data[filtrox]
modulo37 = len(modulo_37)

# Mostrar resultados
print(f"Número de registros total: {modulo37}")

# Filtro de primera consulta 1
fecha_inicio1 = pd.to_datetime('01/09/2022', dayfirst=True, format='%d/%m/%Y')
fecha_fin1 = pd.to_datetime('30/09/2022', dayfirst=True, format='%d/%m/%Y')

filtro1 = (
    append_data['PRACTICA'].str.contains(expresion_regular3, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio1) &
    (append_data['FECHA_TURNO'] <= fecha_fin1)
)

primera_1 = append_data[filtro1]
num_consulta1= len(primera_1)

# Filtro de primera consulta 2
fecha_inicio2 = pd.to_datetime('01/10/2022', dayfirst=True, format='%d/%m/%Y')
fecha_fin2 = pd.to_datetime('31/10/2022', dayfirst=True, format='%d/%m/%Y')

filtro2 = (
    append_data['PRACTICA'].str.contains(expresion_regular3, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio2) &
    (append_data['FECHA_TURNO'] <= fecha_fin2)
)

primera_2 = append_data[filtro2]
num_consulta2= len(primera_2)

# Filtro de primera consulta 3
fecha_inicio3 = pd.to_datetime('01/11/2022', dayfirst=True, format='%d/%m/%Y')
fecha_fin3 = pd.to_datetime('30/11/2022', dayfirst=True, format='%d/%m/%Y')

filtro3 = (
    append_data['PRACTICA'].str.contains(expresion_regular3, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio3) &
    (append_data['FECHA_TURNO'] <= fecha_fin3)
)

primera_3 = append_data[filtro3]
num_consulta3= len(primera_3)

# Filtro de primera consulta 4
fecha_inicio4 = pd.to_datetime('01/12/2022', dayfirst=True, format='%d/%m/%Y')
fecha_fin4 = pd.to_datetime('31/12/2022', dayfirst=True, format='%d/%m/%Y')

filtro4 = (
    append_data['PRACTICA'].str.contains(expresion_regular3, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio4) &
    (append_data['FECHA_TURNO'] <= fecha_fin4)
)

primera_4 = append_data[filtro4]
num_consulta4= len(primera_4)

# Filtro de primera consulta 5
fecha_inicio5 = pd.to_datetime('01/01/2023', dayfirst=True, format='%d/%m/%Y')
fecha_fin5 = pd.to_datetime('31/01/2023', dayfirst=True, format='%d/%m/%Y')

filtro5 = (
    append_data['PRACTICA'].str.contains(expresion_regular3, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio5) &
    (append_data['FECHA_TURNO'] <= fecha_fin5)
)

primera_5 = append_data[filtro5]
num_consulta5= len(primera_5)

# Filtro de primera consulta 6
fecha_inicio6 = pd.to_datetime('01/02/2023', dayfirst=True, format='%d/%m/%Y')
fecha_fin6 = pd.to_datetime('28/02/2023', dayfirst=True, format='%d/%m/%Y')

filtro6 = (
    append_data['PRACTICA'].str.contains(expresion_regular3, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio6) &
    (append_data['FECHA_TURNO'] <= fecha_fin6)
)

primera_6 = append_data[filtro6]
num_consulta6= len(primera_6)

# Filtro de primera consulta 7
fecha_inicio7 = pd.to_datetime('01/03/2023', dayfirst=True, format='%d/%m/%Y')
fecha_fin7 = pd.to_datetime('31/03/2023', dayfirst=True, format='%d/%m/%Y')

filtro7 = (
    append_data['PRACTICA'].str.contains(expresion_regular3, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio7) &
    (append_data['FECHA_TURNO'] <= fecha_fin7)
)

primera_7 = append_data[filtro7]
num_consulta7= len(primera_7)

# Filtro de primera consulta 8
fecha_inicio8 = pd.to_datetime('01/04/2023', dayfirst=True, format='%d/%m/%Y')
fecha_fin8 = pd.to_datetime('30/04/2023', dayfirst=True, format='%d/%m/%Y')

filtro8 = (
    append_data['PRACTICA'].str.contains(expresion_regular3, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio8) &
    (append_data['FECHA_TURNO'] <= fecha_fin8)
)

primera_8 = append_data[filtro8]
num_consulta8= len(primera_8)

# Filtro de primera consulta 9
fecha_inicio9 = pd.to_datetime('01/05/2023', dayfirst=True, format='%d/%m/%Y')
fecha_fin9 = pd.to_datetime('30/05/2023', dayfirst=True, format='%d/%m/%Y')

filtro9 = (
    append_data['PRACTICA'].str.contains(expresion_regular3, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio9) &
    (append_data['FECHA_TURNO'] <= fecha_fin9)
)

primera_9 = append_data[filtro9]
num_consulta9= len(primera_9)

# Filtro de primera consulta 10
fecha_inicio10 = pd.to_datetime('01/06/2023', dayfirst=True, format='%d/%m/%Y')
fecha_fin10 = pd.to_datetime('30/06/2023', dayfirst=True, format='%d/%m/%Y')

filtro10 = (
    append_data['PRACTICA'].str.contains(expresion_regular3, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio10) &
    (append_data['FECHA_TURNO'] <= fecha_fin10)
)

primera_10 = append_data[filtro10]
num_consulta10= len(primera_10)

# Filtro de primera consulta 11
fecha_inicio11 = pd.to_datetime('01/07/2023', dayfirst=True, format='%d/%m/%Y')
fecha_fin11 = pd.to_datetime('31/07/2023', dayfirst=True, format='%d/%m/%Y')

filtro11 = (
    append_data['PRACTICA'].str.contains(expresion_regular3, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio11) &
    (append_data['FECHA_TURNO'] <= fecha_fin11)
)

primera_11 = append_data[filtro11]
num_consulta11= len(primera_11)

# Filtro de primera consulta 12
fecha_inicio12 = pd.to_datetime('01/08/2023', dayfirst=True, format='%d/%m/%Y')
fecha_fin12 = pd.to_datetime('30/08/2023', dayfirst=True, format='%d/%m/%Y')

filtro12 = (
    append_data['PRACTICA'].str.contains(expresion_regular3, na=False) &
    (append_data['FECHA_TURNO'] >= fecha_inicio12) &
    (append_data['FECHA_TURNO'] <= fecha_fin12)
)

primera_12 = append_data[filtro12]
num_consulta12= len(primera_12)


# Datos de número de consultas
num_consultas = [
    num_consulta1, num_consulta2, num_consulta3, num_consulta4,
    num_consulta5, num_consulta6, num_consulta7, num_consulta8,
    num_consulta9, num_consulta10, num_consulta11, num_consulta12
]

promedio = np.mean(num_consultas)
print("Promedio de registros por mes:", promedio)

# Etiquetas de los filtros
etiquetas = [
    "Septiembre 2022", "Octubre 2022", "Noviembre 2022", "Diciembre 2022",
    "Enero 2023", "Febrero 2023", "Marzo 2023", "Abril 2023",
    "Mayo 2023", "Junio 2023", "Julio 2023", "Agosto 2023"
]

fig = go.Figure()

fig.add_trace(
    go.Bar(
        x=etiquetas,
        y=num_consultas,
        text=num_consultas,
        textposition='auto',
        marker_color='purple',
        marker_line_color='black',
        marker_line_width=1.5,
    )
)

# Línea del promedio
fig.add_trace(
    go.Scatter(
        x=etiquetas,
        y=[promedio] * len(etiquetas),
        mode='lines',
        name=f"Promedio: {promedio:.2f}",
        line=dict(color='red', dash='dash'),
    )
)


fig.update_layout(
    title="Cantidad de practicas dentro de módulo 37 (cirugias y lasers)",
    xaxis_title="Mes",
    yaxis_title="Número de registros",
    xaxis_tickangle=-45,
    template="plotly_white"
)
fig.show()
# Out:
# Número de registros total: 2672
# Promedio de registros por mes: 222.66666666666666
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
